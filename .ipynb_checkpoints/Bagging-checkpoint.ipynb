# %% [markdown]
# # Bagging (Bootstrap Aggregation)

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
# Sklearn's dataset: some small datasets
df = datasets.load_wine(as_frame=True) 
# as_frame is for not loosing the feature name

#print(df)
X = df.data
print(X.columns)
y = df.target
print(y)
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline'],
#       dtype='object')
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 173    2
# 174    2
# 175    2
# 176    2
# 177    2
# Name: target, Length: 178, dtype: int64

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(X,y, 
                                                    test_size =0.25, random_state=22 )

# %%
#Decision Tree Classifier
dtree = DecisionTreeClassifier(random_state=22)
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=22)

# %%
#predicting and checking accuracy
y_pred_train = dtree.predict(X_train)
train_accu = accuracy_score(y_train,y_pred_train)
print('Trained data accuracy= ',train_accu)
y_pred_test = dtree.predict(X_test)
test_acc = accuracy_score(y_test,y_pred_test)
print('Test Data accuracy= ',test_acc)
# Out:
# Trained data accuracy=  1.0
# Test Data accuracy=  0.8222222222222222

# %% [markdown]
# ## Bagging

# %%
from sklearn.ensemble import BaggingClassifier

# %%
# values for number of estimators
estimator_range = [2,4,6,8,10,12,14,16]

# %%
models = []
scores = []

for n_estimators in estimator_range:
    
    # Create bagging classifier
    clf = BaggingClassifier(n_estimators=n_estimators, 
                            random_state=22)
    # Fit the model & predict
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    
    # Accuracy
    acc = accuracy_score(y_test,y_pred)
    print('For estimator=', n_estimators, 
          'accuracy score is: ', acc)
    
    # Create list of model and accuracy scores
    models.append(clf)
    
    scores.append(acc)
# Out:
# For estimator= 2 accuracy score is:  0.8222222222222222
# For estimator= 4 accuracy score is:  0.8666666666666667
# For estimator= 6 accuracy score is:  0.9333333333333333
# For estimator= 8 accuracy score is:  0.9333333333333333
# For estimator= 10 accuracy score is:  0.9555555555555556
# For estimator= 12 accuracy score is:  0.9555555555555556
# For estimator= 14 accuracy score is:  0.9555555555555556
# For estimator= 16 accuracy score is:  0.9333333333333333

# %% [markdown]
# ### Explanation.
# By change of estimator the accuracy changes.

# %% [markdown]
# ## Visualising Improvemnt in Accuracy Score

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9,6))
plt.plot(estimator_range,scores)

plt.xlabel('n_estimator')
plt.ylabel('scores')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Out-of-Bag Observations (obb)
# As bootstrapping chooses random subsets of observations to create classifiers, there are observations that are left out in the selection process.obb_score=True evalues the model with out-of-bag score.

# %%
oob_model = BaggingClassifier(n_estimators=12, oob_score=True,
                             random_state=22)
# n_estimators=12 was the best in the previous run

oob_model.fit(X_train,y_train)
score= oob_model.oob_score_
print(score)
# Out:
# 0.9398496240601504

# %% [markdown]
# ## Visualising Decision Tress in the Bagging Classifier

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(30,20))
plot_tree(clf.estimators_[0], feature_names = X.columns)
# Out:
# [Text(767.25, 951.3000000000001, 'proline <= 727.5\ngini = 0.611\nsamples = 82\nvalue = [54, 60, 19]'),
#  Text(418.5, 679.5, 'flavanoids <= 1.335\ngini = 0.339\nsamples = 47\nvalue = [0, 58, 16]'),
#  Text(279.0, 407.70000000000005, 'hue <= 0.92\ngini = 0.266\nsamples = 15\nvalue = [0, 3, 16]'),
#  Text(139.5, 135.89999999999998, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 16]'),
#  Text(418.5, 135.89999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0]'),
#  Text(558.0, 407.70000000000005, 'gini = 0.0\nsamples = 32\nvalue = [0, 55, 0]'),
#  Text(1116.0, 679.5, 'flavanoids <= 1.605\ngini = 0.159\nsamples = 35\nvalue = [54, 2, 3]'),
#  Text(837.0, 407.70000000000005, 'color_intensity <= 4.325\ngini = 0.375\nsamples = 3\nvalue = [0, 1, 3]'),
#  Text(697.5, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(976.5, 135.89999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3]'),
#  Text(1395.0, 407.70000000000005, 'magnesium <= 147.0\ngini = 0.036\nsamples = 32\nvalue = [54, 1, 0]'),
#  Text(1255.5, 135.89999999999998, 'gini = 0.0\nsamples = 31\nvalue = [54, 0, 0]'),
#  Text(1534.5, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]')]
